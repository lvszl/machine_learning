# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# linear regression
# 载入数据
linx = np.loadtxt('./ex5Data/ex5Linx.dat')
liny = np.loadtxt('./ex5Data/ex5Liny.dat')

# 绘图
plt.scatter(linx, liny, color='red')

# %%
# 增加x**2,...,x**5项：
print(linx)
linx_plus = [np.ones((len(linx), 1)), linx.reshape(-1, 1), linx**2, linx**3, linx**4, linx**5]
print(linx_plus)
print(linx_plus[0])
# Out:
# [-0.99768 -0.69574 -0.40373 -0.10236  0.22024  0.47742  0.82229]
# [array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]]), array([[-0.99768],
#        [-0.69574],
#        [-0.40373],
#        [-0.10236],
#        [ 0.22024],
#        [ 0.47742],
#        [ 0.82229]]), array([0.99536538, 0.48405415, 0.16299791, 0.01047757, 0.04850566,
#        0.22792986, 0.67616084]), array([-0.99305613, -0.33677583, -0.06580715, -0.00107248,  0.01068289,
#         0.10881827,  0.5560003 ]), array([9.90752244e-01, 2.34308418e-01, 2.65683196e-02, 1.09779465e-04,
#        2.35279882e-03, 5.19520194e-02, 4.57193487e-01]), array([-9.88453699e-01, -1.63017739e-01, -1.07264277e-02, -1.12370260e-05,
#         5.18180412e-04,  2.48029331e-02,  3.75945633e-01])]
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]
